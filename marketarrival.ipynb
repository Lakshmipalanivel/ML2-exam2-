# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as  sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression as LS
from sklearn.metrics import mean_squared_error as mse
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# %%
market=pd.read_csv("C:/Users/hp/Documents/MonthWiseMarketArrivals_Clean.csv")

# %%
market.head()
# Out:
#        market    month  year  quantity  priceMin  priceMax  priceMod state  \
# 0  ABOHAR(PB)  January  2005      2350       404       493       446    PB
# 1  ABOHAR(PB)  January  2006       900       487       638       563    PB
# 2  ABOHAR(PB)  January  2010       790      1283      1592      1460    PB
# 3  ABOHAR(PB)  January  2011       245      3067      3750      3433    PB
# 4  ABOHAR(PB)  January  2012      1035       523       686       605    PB
#
#      city          date
# 0  ABOHAR  January-2005
# 1  ABOHAR  January-2006
# 2  ABOHAR  January-2010
# 3  ABOHAR  January-2011
# 4  ABOHAR  January-2012

# %%
market.set_index(["date"], inplace = True,append = True, drop = False)

# %%
market.head()
# Out:
#                     market    month  year  quantity  priceMin  priceMax  \
#   date
# 0 January-2005  ABOHAR(PB)  January  2005      2350       404       493
# 1 January-2006  ABOHAR(PB)  January  2006       900       487       638
# 2 January-2010  ABOHAR(PB)  January  2010       790      1283      1592
# 3 January-2011  ABOHAR(PB)  January  2011       245      3067      3750
# 4 January-2012  ABOHAR(PB)  January  2012      1035       523       686
#
#                 priceMod state    city          date
#   date
# 0 January-2005       446    PB  ABOHAR  January-2005
# 1 January-2006       563    PB  ABOHAR  January-2006
# 2 January-2010      1460    PB  ABOHAR  January-2010
# 3 January-2011      3433    PB  ABOHAR  January-2011
# 4 January-2012       605    PB  ABOHAR  January-2012

# %%
df = pd.DataFrame(market)

# %%
print(df)
# Out:
#                          market     month  year  quantity  priceMin  priceMax  \
#       date
# 0     January-2005   ABOHAR(PB)   January  2005      2350       404       493
# 1     January-2006   ABOHAR(PB)   January  2006       900       487       638
# 2     January-2010   ABOHAR(PB)   January  2010       790      1283      1592
# 3     January-2011   ABOHAR(PB)   January  2011       245      3067      3750
# 4     January-2012   ABOHAR(PB)   January  2012      1035       523       686
# ...                         ...       ...   ...       ...       ...       ...
# 10222 December-2011   YEOLA(MS)  December  2011    131326       282       612
# 10223 December-2012   YEOLA(MS)  December  2012    207066       485      1327
# 10224 December-2013   YEOLA(MS)  December  2013    215883       472      1427
# 10225 December-2014   YEOLA(MS)  December  2014    201077       446      1654
# 10226 December-2015   YEOLA(MS)  December  2015    223315       609      1446
#
#                      priceMod state    city           date
#       date
# 0     January-2005        446    PB  ABOHAR   January-2005
# 1     January-2006        563    PB  ABOHAR   January-2006
# 2     January-2010       1460    PB  ABOHAR   January-2010
# 3     January-2011       3433    PB  ABOHAR   January-2011
# 4     January-2012        605    PB  ABOHAR   January-2012
# ...                       ...   ...     ...            ...
# 10222 December-2011       526    MS   YEOLA  December-2011
# 10223 December-2012      1136    MS   YEOLA  December-2012
# 10224 December-2013      1177    MS   YEOLA  December-2013
# 10225 December-2014      1456    MS   YEOLA  December-2014
# 10226 December-2015      1126    MS   YEOLA  December-2015
#
# [10227 rows x 10 columns]

# %%
df.drop(["market","month","year","priceMin","priceMax","priceMod","state","city"],axis=1)
# Out:
#                         month  quantity           date
#       date
# 0     January-2005    January      2350   January-2005
# 1     January-2006    January       900   January-2006
# 2     January-2010    January       790   January-2010
# 3     January-2011    January       245   January-2011
# 4     January-2012    January      1035   January-2012
# ...                       ...       ...            ...
# 10222 December-2011  December    131326  December-2011
# 10223 December-2012  December    207066  December-2012
# 10224 December-2013  December    215883  December-2013
# 10225 December-2014  December    201077  December-2014
# 10226 December-2015  December    223315  December-2015
#
# [10227 rows x 3 columns]

# %%
np.random.seed(2014)
df = pd.DataFrame({'A':np.random.rand(5)})

# %%
print(df)
# Out:
#           A
# 0  0.185581
# 1  0.301659
# 2  0.337738
# 3  0.990038
# 4  0.396088

# %%
date = pd.date_range('January-2005', 'January-2014')
date = date[date.month.isin([1])].strftime('%m-%d')

# %%
print (len(date))
# Out:
# 280

# %%
market.index = date
print (df.head(10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14412/1357034489.py in <module>
# ----> 1 market.index = date
#       2 print (df.head(10))
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#     767         self._clear_item_cache()
#     768
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     214     def set_axis(self, axis: int, new_labels: Index) -> None:
#     215         # Caller is responsible for ensuring we have an Index object.
# --> 216         self._validate_set_axis(axis, new_labels)
#     217         self.axes[axis] = new_labels
#     218
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\base.py in _validate_set_axis(self, axis, new_labels)
#      55
#      56         elif new_len != old_len:
# ---> 57             raise ValueError(
#      58                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      59                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 10227 elements, new values have 280 elements
